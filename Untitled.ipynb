# %%
import pandas as pd
df=pd.read_csv('car_sales_data.csv')
df.tail(10)
# Out:
#        Make    Model  Year  Engine Size  Mileage Fuel Type Transmission  \
# 9990    BMW  Model A  2011          1.4    17341    Petrol    Automatic
# 9991   Audi  Model C  2018          3.0   170277    Diesel       Manual
# 9992   Ford  Model C  2017          4.3    49914    Diesel    Automatic
# 9993  Honda  Model C  2013          2.8    71132    Diesel       Manual
# 9994    BMW  Model C  2019          1.5     5949  Electric       Manual
# 9995   Ford  Model D  2008          2.4    46784  Electric       Manual
# 9996    BMW  Model D  2002          3.2     6621    Petrol       Manual
# 9997   Ford  Model B  2011          3.7    61037    Diesel       Manual
# 9998  Honda  Model B  2019          3.1   190175  Electric       Manual
# 9999    BMW  Model A  2016          1.1   199497  Electric    Automatic
#
#              Price
# 9990  25673.452173
# 9991  21291.887659
# 9992  32908.682063
# 9993  22904.611332
# 9994  31457.924871
# 9995  26642.475776
# 9996  27486.488777
# ...

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Size', 'Mileage', 'Fuel Type',
#        'Transmission', 'Price'],
#       dtype='object')
